# %% [markdown]
# Name: Douglas Marshall
# ASS:7.4-7.7
# Def:Modifys elements and an array and print the array.

# %%
things = ['mozzarella', 'cinderella', 'salmonella']
print(things)
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %%
things[1] = 'Cinderella'
print(things)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %% [markdown]
# 7.5 Yes, it did change.

# %%
things[0] = things[0].upper()
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %%
del things[-1]
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella']
