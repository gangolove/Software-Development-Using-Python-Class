# %%
#Name: Douglas Marshall
#ASS:Mod 3 Tutorial
#DEF: Sorts an array from least to greatest



def sort012(arr):
    n = len(arr)
    
    
    lo = 0
    hi = n - 1
    mid = 0
    
    # goes through loop til mid surpasses hi
    while mid <= hi:
        if arr[mid] == 0:
            
            # 0 goes to lo
            arr[lo], arr[mid] = arr[mid], arr[lo]
            lo += 1
            mid += 1
        elif arr[mid] == 1:
            #1 stays mid
            mid += 1
        else:
            #2 goes to high
             arr[mid], arr[hi] = arr[hi], arr[mid]
            hi -= 1
