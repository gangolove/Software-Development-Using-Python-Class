# %% [raw]
# Name: Douglas Marshall
# ASS:9.1-9.2
# Def:First returns array of harry potter characters. 2nd returns odd numbers and prints 3rd value.

# %% [markdown]
# 9.1

# %%
def good():
    return ['Harry', 'Ron', 'Hermione']

# %% [markdown]
# 9.2

# %%
def get_odds():

    odd_nums = []
    
    for number in range(10):
        if number % 2 == 1:
            odd_nums.append(number)
    return odd_nums

odds = get_odds()

for i in odds:
    if i == 2:
        print(odds[i])
