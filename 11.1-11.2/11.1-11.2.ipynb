# %% [markdown]
# #name:Douglas Marshall
# #ass:11.1-11.2
# #Des:calls function

# %%
import zoo
zoo.hours()
# Out:
# Open 9-5 daily

# %%
import zoo as menagerie
menagerie.hours()
# Out:
# Open 9-5 daily
