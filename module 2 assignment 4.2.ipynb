# %% [markdown]
# Name: Douglas Marshall
# Ass#: 4.2
# Description: Tells which fruit is not green and is smal. Boollean value can be edited to describe different fruits.

# %%
green = False
small = True

if green and small:
    print('pea')
    
if green and not small:
    print('watermelon')
    
if not green and small:
    print('cherry')
    
if not green and not small:
    print('pumpkin')
